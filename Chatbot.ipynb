# %%
import requests
AUTH_TOKEN = "xxxx"

# %%
url = "https://api.groq.com/openai/v1/chat/completions"

def ask_groq(question):
  response = requests.post(

      url = "https://api.groq.com/openai/v1/chat/completions",

      headers = {
          "Content-Type": "application/json",
          "Authorization": f"Bearer {AUTH_TOKEN}"
      },

      json = {
          "model": "llama-3.3-70b-versatile",
          "temperature": 0.6,
          "messages": [
              {"role": "system", "content": "You are a helpful chatbot."},
               {"role": "user", "content": question}
              ]
      }
          )
  output = response.json()
  return output["choices"][0]["message"]["content"]

# %%
print("Chatbot started! Type 'exit' to stop.\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Bot: Goodbye!")
        break

    bot_reply = ask_groq(user_input)
    print("Bot:", bot_reply)
# Out:
# Chatbot started! Type 'exit' to stop.
#
# You: what is 5+5
# Bot: 5 + 5 = 10
# You: what is your name?
# Bot: I don't have a personal name, but I'm often referred to as "Assistant" or "Chatbot" by users. If you'd like, I can suggest some names for you to call me, or you can even give me a nickname of your choice. What would you like to call me?
# You: exit
# Bot: Goodbye!
